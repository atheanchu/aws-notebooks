# %%
import boto3
import json

# %% [markdown]
# # Creating a job

# %%
# Use the describe_endpoints method to request an endpoint.
client = boto3.client('mediaconvert', endpoint_url='https://qzovegirb.mediaconvert.ap-northeast-2.amazonaws.com')

# %%
with open("./config/MediaConvertJobConfig.json", "r") as jsonfile:
  job_object = json.load(jsonfile)

print(job_object)

# %%
client.create_job(**job_object)
